# %% [markdown]
# <a href="https://colab.research.google.com/github/RachitSankhla/sarkaar-ka-kaam/blob/main/CGPA%20and%20Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as pl

# %%
y=[20,30,40,50]
x=[2,3,4,5]
pl.plot(x,y,"o-b")
pl.xlabel('CGPA')
pl.ylabel('salary')
pl.title('CGPA and salary distribution')
pl.show()
